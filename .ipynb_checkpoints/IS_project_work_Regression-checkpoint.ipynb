# %%
# Load libraries
from pandas import read_csv
from pandas.plotting import scatter_matrix
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn import tree

from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
from sklearn.model_selection import GridSearchCV
from sklearn.inspection import permutation_importance
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor

import statistics
from sklearn.preprocessing import MinMaxScaler


random_state = 42
train_size = 0.7

# %% [markdown]
# <h2>Importing and exploring the dataset</h2>

# %% [markdown]
# At first glance we can already see that some columns have numerical values while other seem to have categorical data.
# <br>
# Some raws contain missing values.

# %%
url = "direct_matching_20240213.csv"
df_raw = read_csv(url, sep=";", header=0)

df_raw.head(n=10)
# Out:
#      cand_id         job_id  distance_km  match_score  match_rank cand_gender  \
# 0  5,664,912  OFF_1011_1427    32.327042    99.573387           1        Male
# 1  4,999,120  OFF_1011_1427    15.595593    99.210564           2        Male
# 2  5,413,671  OFF_1011_1427    31.348877    99.118614           3      Female
# 3  5,965,090  OFF_1011_1427    66.315598    97.409767           4        Male
# 4  5,771,219  OFF_1011_1427    15.595593    97.323875           5      Female
# 5  2,216,205  OFF_1011_1427    24.946939    96.922318           6        Male
# 6  4,594,051  OFF_1011_1427    27.959969    96.245216           7        Male
# 7  5,148,878  OFF_1011_1427    25.512180    96.235245           8        Male
# 8  5,933,345  OFF_1011_1427    28.856832    96.009712           9      Female
# 9  7,204,128  OFF_1011_1427    31.348877    95.802277          10      Female
#
#   cand_age_bucket cand_domicile_province   cand_domicile_region  \
# 0           45-54                     UD  FRIULI VENEZIA GIULIA
# 1           35-44                     UD  FRIULI VENEZIA GIULIA
# 2           45-54                     UD  FRIULI VENEZIA GIULIA
# 3           15-24                     TS  FRIULI VENEZIA GIULIA
# 4           35-44                     UD  FRIULI VENEZIA GIULIA
# 5           55-74                     UD  FRIULI VENEZIA GIULIA
# 6           55-74                     UD  FRIULI VENEZIA GIULIA
# 7           25-34                     UD  FRIULI VENEZIA GIULIA
# 8           45-54                     GO  FRIULI VENEZIA GIULIA
# 9           35-44                     UD  FRIULI VENEZIA GIULIA
#
#                    cand_education   job_contract_type  \
# 0                             NaN  Lavoro subordinato
# 1                             NaN  Lavoro subordinato
# 2                             NaN  Lavoro subordinato
# 3                             NaN  Lavoro subordinato
# 4                             NaN  Lavoro subordinato
# 5  Diploma / Accademia : Geometra  Lavoro subordinato
# 6                             NaN  Lavoro subordinato
# 7                             NaN  Lavoro subordinato
# 8                             NaN  Lavoro subordinato
# 9                             NaN  Lavoro subordinato
#
#                            job_professional_category  \
# 0  Geometra e tecnico di costruzioni civili e ind...
# 1  Geometra e tecnico di costruzioni civili e ind...
# 2  Geometra e tecnico di costruzioni civili e ind...
# 3  Geometra e tecnico di costruzioni civili e ind...
# 4  Geometra e tecnico di costruzioni civili e ind...
# 5  Geometra e tecnico di costruzioni civili e ind...
# 6  Geometra e tecnico di costruzioni civili e ind...
# 7  Geometra e tecnico di costruzioni civili e ind...
# 8  Geometra e tecnico di costruzioni civili e ind...
# 9  Geometra e tecnico di costruzioni civili e ind...
#
#                        job_sector job_work_province
# 0  Progettisti / Design / Grafici               UD
# 1  Progettisti / Design / Grafici               UD
# 2  Progettisti / Design / Grafici               UD
# 3  Progettisti / Design / Grafici               UD
# 4  Progettisti / Design / Grafici               UD
# 5  Progettisti / Design / Grafici               UD
# 6  Progettisti / Design / Grafici               UD
# 7  Progettisti / Design / Grafici               UD
# 8  Progettisti / Design / Grafici               UD
# 9  Progettisti / Design / Grafici               UD

# %% [markdown]
# as we can see there are some things to change like the candidate education (lots of NaN values) or decide the classification column.

# %%
df_raw.count()
# Out:
# cand_id                      8647
# job_id                       8647
# distance_km                  8647
# match_score                  8647
# match_rank                   8647
# cand_gender                  8647
# cand_age_bucket              8646
# cand_domicile_province       8644
# cand_domicile_region         8642
# cand_education               2341
# job_contract_type            8647
# job_professional_category    8647
# job_sector                   8647
# job_work_province            8647
# dtype: int64

# %%
n_jobs = df_raw["job_id"].nunique()
print("number of unique jobs:", n_jobs)
# Out:
# number of unique jobs: 865

# %%
df_raw[df_raw["cand_domicile_province"].isna()]
# Out:
#         cand_id          job_id  distance_km  match_score  match_rank  \
# 627   5,449,407   OFF_1745_0198    34.129036    99.759705           9
# 4493  5,262,317    OFF_789_0870    80.433472    99.623642           6
# 8301  6,523,103  ORD_48061_0590    82.721603    96.154732           5
#
#      cand_gender cand_age_bucket cand_domicile_province cand_domicile_region  \
# 627         Male           35-44                    NaN             CAMPANIA
# 4493        Male           25-34                    NaN             CAMPANIA
# 8301        Male           15-24                    NaN                  NaN
#
#      cand_education   job_contract_type  \
# 627             NaN  Lavoro subordinato
# 4493            NaN  Lavoro subordinato
# 8301            NaN  Lavoro subordinato
#
#                          job_professional_category  \
# 627                         Carrellista/Mulettista
# 4493     analista finanziario/analista finanziaria
# 8301  Operaio Generico Elettronico/ Elettrotecnico
#
#                                         job_sector job_work_province
# 627              Magazzino / Logistica / Trasporti               MN
# 4493  Banche / Assicurazioni / Istituti di Credito               FI
# 8301                               Operai Generici               BZ

# %% [markdown]
# From what we can see here there is some missing data (we have 8647 candidates and 8644 domicile provinces) so I've decided to drop the missing data raws except for "cand_education" where I replace missing values with "no info" for those candidates that haven't specified their education.

# %%
df_clean = df_raw.copy()
df_clean["cand_education"] = df_clean["cand_education"].fillna(value="no info")
df_clean = df_clean.dropna()
df_clean = df_clean.drop(["cand_id", "job_id", "match_rank"], axis=1)
df_clean.count()
# Out:
# distance_km                  8639
# match_score                  8639
# cand_gender                  8639
# cand_age_bucket              8639
# cand_domicile_province       8639
# cand_domicile_region         8639
# cand_education               8639
# job_contract_type            8639
# job_professional_category    8639
# job_sector                   8639
# job_work_province            8639
# dtype: int64

# %% [markdown]
# Being that "match_score" and "match_rank" are stricktly correlated and they mean the same thing, I've decided to drop one.
#
# On the other hand "cand_id" is not useful for the matching and the details of the candidate are described by other columns.
# Same for "job_id".
#
# now the dataset is clean and ready to be used.

# %% [markdown]
# <h2>Regression</h2>

# %% [markdown]
# Now I want to predict the data with a regressor so I shall transform strings to numerical data that can be handled.

# %%
target = "match_score"

print("age ranges:", df_clean["cand_age_bucket"].unique())

numerical_columns = ["distance_km", "match_score"]
categorical_columns = df_clean.drop(numerical_columns, axis=1).columns

print("\nnumber of categories per column:")
df_clean[categorical_columns].nunique()
# Out:
# age ranges: ['45-54' '35-44' '15-24' '55-74' '25-34']
#
# number of categories per column:
# cand_gender                    2
# cand_age_bucket                5
# cand_domicile_province        78
# cand_domicile_region          18
# cand_education               434
# job_contract_type              3
# job_professional_category    247
# job_sector                    26
# job_work_province             53
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

l_encoders = {}

for column in categorical_columns:
    le = LabelEncoder()
    df_clean[column] = le.fit_transform(df_clean[column])
    l_encoders[column] = le

# %% [markdown]
# Now the categorical columns have been encoded and df is the dataframe I can use for a regressor

# %%
print("shape:",df_clean.shape)
df_clean.head()
# Out:
# shape: (8639, 11)
#    distance_km  match_score  cand_gender  cand_age_bucket  \
# 0    32.327042    99.573387            1                3
# 1    15.595593    99.210564            1                2
# 2    31.348877    99.118614            0                3
# 3    66.315598    97.409767            1                0
# 4    15.595593    97.323875            0                2
#
#    cand_domicile_province  cand_domicile_region  cand_education  \
# 0                      71                     4             433
# 1                      71                     4             433
# 2                      71                     4             433
# 3                      69                     4             433
# 4                      71                     4             433
#
#    job_contract_type  job_professional_category  job_sector  job_work_province
# 0                  0                         76          22                 48
# 1                  0                         76          22                 48
# 2                  0                         76          22                 48
# 3                  0                         76          22                 48
# 4                  0                         76          22                 48

# %%
X = df_clean.drop(target ,axis = 1)
y = df_clean[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=random_state, train_size=train_size)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (6047, 10) (2592, 10) (6047,) (2592,)

# %%
model = DecisionTreeRegressor(random_state=random_state)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print("R^2 Score:", r2)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)
# Out:
# R^2 Score: -0.24796559387212658
# Mean Squared Error: 1.204276766648551
# Root Mean Squared Error: 1.097395446795981
# Mean Absolute Error: 0.24392813438560945

# %% [markdown]
# The results are pretty poor, let's explore the dataset once again

# %%
df_clean.describe()
# Out:
#        distance_km  match_score  cand_gender  cand_age_bucket  \
# count  8639.000000  8639.000000  8639.000000      8639.000000
# mean     29.754485    99.634336     0.550990         1.892349
# std      23.484031     1.071206     0.497422         1.168977
# min       0.000000    69.610825     0.000000         0.000000
# 25%      12.252331    99.677177     0.000000         1.000000
# 50%      23.437698    99.856194     1.000000         2.000000
# 75%      41.751572    99.932739     1.000000         3.000000
# max      99.966797    99.999214     1.000000         4.000000
#
#        cand_domicile_province  cand_domicile_region  cand_education  \
# count             8639.000000           8639.000000     8639.000000
# mean                38.905660              8.214955      370.336150
# std                 23.536162              4.351507      123.640476
# min                  0.000000              0.000000        0.000000
# 25%                 11.000000              7.000000      407.000000
# 50%                 38.000000              7.000000      433.000000
# 75%                 59.000000             10.000000      433.000000
# max                 77.000000             17.000000      433.000000
#
#        job_contract_type  job_professional_category   job_sector  \
# count        8639.000000                8639.000000  8639.000000
# mean            0.688969                 136.567195    14.744878
# std             0.949236                  68.003542     5.320387
# min             0.000000                   0.000000     0.000000
# 25%             0.000000                  89.000000    12.000000
# 50%             0.000000                 126.000000    18.000000
# 75%             2.000000                 203.000000    18.000000
# max             2.000000                 246.000000    25.000000
#
#        job_work_province
# count        8639.000000
# mean           27.001852
# std            15.734351
# min             0.000000
# 25%             9.000000
# 50%            26.000000
# 75%            41.000000
# max            52.000000

# %%
import seaborn as sns

sns.heatmap(df_clean.corr())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
df_clean["distance_km"].hist(bins=30, edgecolor="black", grid=False)
plt.title("Distance distribution")
plt.show()

# %% [markdown]
# Even with the logarithmic scale we can see that the values of the target column "match_score" are skewed towards the high end (92-100 range).
#
# This could mean that the outliers make the regression difficult.

# %%
plt.figure(figsize=(15,8))
plt.hist(df_clean["match_score"], bins=30, edgecolor="black")

plt.locator_params(axis="x", nbins=30, tight=True)
plt.yscale("log")
plt.show()

# %% [markdown]
# Let's use the IQR technique where we keep only a part of the total dataset.

# %%
Q1 = df_clean["match_score"].quantile(0.25)
Q3 = df_clean["match_score"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Q1:",Q1)
print("Q3:",Q3)
print("IQR:",IQR)
print()
print(f"Range of good \"match_score\": {lower_bound:.3f} - {upper_bound:.3f}")
print()

df_filtered = df_clean[(df_clean["match_score"] >= lower_bound) & (df_clean["match_score"] <= upper_bound)]
print("number of raws in the filtered dataframe: ", df_filtered.shape[0])
# Out:
# Q1: 99.67717743
# Q3: 99.93273926
# IQR: 0.2555618300000049
#
# Range of good "match_score": 99.294 - 100.316
#
# number of raws in the filtered dataframe:  7711

# %%
plt.figure(figsize=(15,8))
plt.hist(df_filtered["match_score"], bins=30, edgecolor="black")

plt.locator_params(axis="x", nbins=30, tight=True)
plt.yscale("log")
plt.show()

# %%
def show_errors(y_test, y_pred):
    errors = y_test - y_pred
    errors = abs(errors.values)
    
    plt.figure(figsize=(15, 8))
    plt.hist(errors, bins=20, color="lightgreen" ,edgecolor="black")
    
    max = int(np.max(errors))
    plt.locator_params(axis="x", nbins=20, tight=True)
    plt.locator_params(axis="y", nbins=20, tight=True)
    plt.show()

def print_metrics(y_test, y_pred):
    mse = mean_squared_error(y_test, y_pred)
    rmse = mse ** 0.5
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    
    print(f"R^2 Score: {r2:.3f}")
    print(f"Mean Squared Error: {mse:.3f}")
    print(f"Root Mean Squared Error: {rmse:.3f}")
    print(f"Mean Absolute Error: {mae:.3f}")

def show_feature_importances(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    result = permutation_importance(model, X_test, y_test, n_repeats=15, random_state=random_state, n_jobs=-1)
    sorted_importances_idx = result.importances_mean.argsort()
    importances = pd.DataFrame(
        result.importances[sorted_importances_idx].T,
        columns=X_train.columns[sorted_importances_idx],
    )
    ax = importances.plot.box(vert=False, whis=10)
    ax.set_title("Permutation Importances (test set)")
    ax.axvline(x=0, color="k", linestyle="--")
    ax.set_xlabel("Decrease in score")

# %% [markdown]
# <h3>Fearute importance</h3>

# %%
X_fi = df_filtered.drop(target ,axis = 1)
y_fi = df_filtered[target]

X_train_fi, X_test_fi, y_train_fi, y_test_fi = train_test_split(X_fi, y_fi, random_state=random_state, train_size=train_size)

print(X_train_fi.shape, X_test_fi.shape, y_train_fi.shape, y_test_fi.shape)
# Out:
# (5397, 10) (2314, 10) (5397,) (2314,)

# %%
model = DecisionTreeRegressor(random_state=random_state)
show_feature_importances(model, X_train_fi, y_train_fi, X_test_fi, y_test_fi)

# %%
model = RandomForestRegressor(random_state=random_state)
show_feature_importances(model, X_train_fi, y_train_fi, X_test_fi, y_test_fi)

# %%
model = model = LinearRegression()
show_feature_importances(model, X_train_fi, y_train_fi, X_test_fi, y_test_fi)

# %%
model = model = GradientBoostingRegressor(random_state=random_state)
show_feature_importances(model, X_train_fi, y_train_fi, X_test_fi, y_test_fi)

# %%
model = SVR()
show_feature_importances(model, X_train_fi, y_train_fi, X_test_fi, y_test_fi)

# %% [markdown]
# All the models agree that the three less important features are "job_contract_type", "cand_age_bucket" and "cand_gender" therefore I drop these columns from the dataset and keep only the most important features. ("_if" stands for "important features")

# %%
X = df_filtered.drop([target, "cand_age_bucket", "cand_gender", "cand_education"] ,axis = 1)
y = y_fi = df_filtered[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=random_state, train_size=train_size)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (5397, 7) (2314, 7) (5397,) (2314,)

# %% [markdown]
# <h3>DecisionTreeRegressor<h3>

# %%
model = DecisionTreeRegressor(random_state=random_state)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print_metrics(y_test, y_pred)
show_errors(y_test, y_pred)
# Out:
# R^2 Score: 0.380
# Mean Squared Error: 0.014
# Root Mean Squared Error: 0.120
# Mean Absolute Error: 0.070

# %% [markdown]
# <h3>RandomForestRegressor<h3>

# %%
model = RandomForestRegressor(random_state=random_state)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print_metrics(y_test, y_pred)
show_errors(y_test, y_pred)
# Out:
# R^2 Score: 0.576
# Mean Squared Error: 0.010
# Root Mean Squared Error: 0.099
# Mean Absolute Error: 0.063

# %% [markdown]
# <h3>RandomForestRegressor<h3>

# %%
model = LinearRegression()

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print_metrics(y_test, y_pred)
show_errors(y_test, y_pred)
# Out:
# R^2 Score: 0.039
# Mean Squared Error: 0.022
# Root Mean Squared Error: 0.149
# Mean Absolute Error: 0.115

# %%
model = GradientBoostingRegressor(random_state=random_state)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print_metrics(y_test, y_pred)
show_errors(y_test, y_pred)
# Out:
# R^2 Score: 0.306
# Mean Squared Error: 0.016
# Root Mean Squared Error: 0.127
# Mean Absolute Error: 0.094

# %%
model = SVR()

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print_metrics(y_test, y_pred)
show_errors(y_test, y_pred)
# Out:
# R^2 Score: 0.069
# Mean Squared Error: 0.021
# Root Mean Squared Error: 0.147
# Mean Absolute Error: 0.109

# %% [markdown]
# <h2>Fairness</h2>

# %%
model_rfr = RandomForestRegressor(random_state=random_state)

model_rfr.fit(X_train_fi, y_train_fi)

X_test_fi_male = X_test_fi[X_test_fi["cand_gender"]==1]
X_test_fi_female = X_test_fi[X_test_fi["cand_gender"]==0]

y_test_fi_male = y_test_fi[X_test_fi_male.index]
y_test_fi_female = y_test_fi[X_test_fi_female.index]

y_pred_male = model_rfr.predict(X_test_fi_male)
y_pred_female = model_rfr.predict(X_test_fi_female)

print(f"males: {len(y_pred_male)}")
print(f"females: {len(y_pred_female)}")
# Out:
# males: 1261
# females: 1053

# %%
# unique encoded labels
# np.sort(X_test_fi["cand_gender"].unique())

# specific job sector
# X_test[X_test["job_sector"] == 5]

# %%
MAE_male = mean_absolute_error(y_pred_male, y_test_fi_male)
MAE_female = mean_absolute_error(y_pred_female, y_test_fi_female)

MAE_male/MAE_female
# Out:
# 1.0864330729709786

# %%
mean_male = statistics.mean(y_pred_male)
mean_female = statistics.mean(y_pred_female)

mean_male/mean_female
# Out:
# np.float64(0.9998549823374564)

# %%
X["cand_domicile_province"].nunique()
# Out:
# 77

# %%
model = DecisionTreeRegressor(random_state=random_state)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# attaching the original indexes to the pedicted values
scaler = MinMaxScaler()
y_pred_scaled = scaler.fit_transform(y_pred.reshape(-1, 1)).flatten()
y_pred_indexed = pd.Series(data=y_pred_scaled, index=y_test.index)
y_pred_indexed.shape
# Out:
# (2314,)

# %% [markdown]
# In orter to analize fairness we need to discretize the "distance_km" column, whitch is the only one containing continous values.

# %%
X_test_discretized = X_test.copy()
X_test_discretized["distance_km"] = pd.cut(X_test["distance_km"], bins=[-1,20,40,60,80,101], labels=["very close", "close", "mid", "far", "very far"])
le = LabelEncoder()
X_test_discretized["distance_km"] = le.fit_transform(X_test_discretized["distance_km"])
l_encoders["distance_km"] = le
X_test_discretized.head()
# Out:
#       distance_km  cand_domicile_province  cand_domicile_region  \
# 5817            3                      11                     7
# 7700            3                      49                    13
# 5502            3                      67                    14
# 2808            2                      34                     5
# 4775            3                       7                     7
#
#       job_contract_type  job_professional_category  job_sector  \
# 5817                  0                         81           5
# 7700                  0                        125          18
# 5502                  0                        187          18
# 2808                  0                        206           8
# 4775                  0                        126          18
#
#       job_work_province
# 5817                  9
# 7700                 34
# 5502                 45
# 2808                 40
# 4775                  5

# %% [markdown]
# These two functions will calculate the Disparate Impact and Statistical Parity for all categories in a column.

# %%
def fairness_statistics(column, category):
    A = X_test_discretized[X_test_discretized[column]==category]
    nonA = X_test_discretized[X_test_discretized[column]!=category]
    
    X_test_discretized_A = X_test_discretized[X_test_discretized[column]==category]
    X_test_discretized_nonA = X_test_discretized[X_test_discretized[column]!=category]
    
    y_pred_A = y_pred_indexed[X_test_discretized_A.index]
    y_pred_nonA = y_pred_indexed[X_test_discretized_nonA.index]
    
    mean_A = statistics.mean(y_pred_A)
    mean_nonA = statistics.mean(y_pred_nonA)
    
    return [mean_A/mean_nonA, mean_A-mean_nonA]

def fairness_statistics_df(df_column):
    result = pd.DataFrame(columns=["category name","disparate impact", "statistical parity", "occurrences"])
    for category_number in df_column.unique():
        category_name = l_encoders[df_column.name].inverse_transform([category_number])[0]
        fs = fairness_statistics(df_column.name, category_number)
        occ = len(df_column[df_column==category_number])
        result.loc[len(result)] = [category_name, fs[0], fs[1], occ]
    return result

# %% [markdown]
# We can see some categories that have more than 10% Disparate Impact.
# UMBRIA and SARDEGNA have ratings way below average while having few occurrences.
# On the other hand LOMBARDIA has the most occurences and a rating 11% above the averege.

# %%
fairness_statistics_df(X_test_discretized["cand_domicile_region"])
# Out:
#             category name  disparate impact  statistical parity  occurrences
# 0               LOMBARDIA          1.113586            0.080741         1111
# 1                 TOSCANA          1.043707            0.032727           59
# 2     TRENTINO ALTO ADIGE          0.932348           -0.050763           35
# 3                   LAZIO          1.025116            0.018809           90
# 4          EMILIA ROMAGNA          0.987452           -0.009422          326
# 5   FRIULI VENEZIA GIULIA          0.711825           -0.218629           96
# 6                PIEMONTE          0.939933           -0.045290          224
# 7                  VENETO          0.941786           -0.043979          309
# 8                  MARCHE          0.835239           -0.123716           24
# 9           VALLE D'AOSTA          1.268275            0.200935            7
# 10                LIGURIA          1.022104            0.016568            8
# 11                ABRUZZO          0.947503           -0.039363           13
# 12                 UMBRIA          0.509238           -0.368342            6
# 13                 MOLISE          1.218838            0.164010            2
# 14               SARDEGNA          0.555931           -0.333064            3
# 15                 PUGLIA          1.117452            0.088037            1

# %% [markdown]
# Looking at the discretized distances we can see that only the "very far" has a Disparate Impact greater than 10%.

# %%
fairness_statistics_df(X_test_discretized["distance_km"])
# Out:
#   category name  disparate impact  statistical parity  occurrences
# 0    very close          0.974049           -0.019668          976
# 1           mid          0.995075           -0.003694          299
# 2         close          0.970835           -0.022057          700
# 3           far          1.060404            0.045037          205
# 4      very far          1.153695            0.114193          134

# %%
max(y_test)/min(y_test)
# Out:
# 1.0070675544975796

# %% [markdown]
# <h2>GSCV</h2>

# %%
param_grid = {
    "max_depth": [*range(1,20)],
    "min_samples_split": [*range(2,10,2)]
}

clf = GridSearchCV(DecisionTreeRegressor(random_state=random_state), param_grid, cv=5, scoring="neg_mean_absolute_error", n_jobs=-1)
clf.fit(X_train, y_train)
print(clf.best_params_)
print(clf.best_score_)

best = clf.best_estimator_
y_pred = best.predict(X_test)
r2 = r2_score(y_test, y_pred)
print("R^2 Score:", r2)
# Out:
# {'max_depth': 19, 'min_samples_split': 8}
# -0.0819029920258869
# R^2 Score: 0.36850601117250137

# %%
param_grid = {
    "n_estimators": [5, 25 ,50, 75, 100],
    "max_depth": [*range(4,20,4)],
    "min_samples_split": [*range(2,10,2)]
}

clf = GridSearchCV(RandomForestRegressor(random_state=random_state), param_grid, cv=5, scoring="neg_mean_absolute_error", n_jobs=-1)
clf.fit(X_train, y_train)
print(clf.best_params_)
print(clf.best_score_)

best = clf.best_estimator_
y_pred = best.predict(X_test)
r2 = r2_score(y_test, y_pred)
print("R^2 Score:", r2)
# Out:
# {'max_depth': 16, 'min_samples_split': 2, 'n_estimators': 100}
# -0.07581875643328423
# R^2 Score: 0.5548512133120909

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

plt.scatter(y_test,y_pred)
ax.plot([y_test.min(), y_test.max()], [y_test.min(),y_test.max()], color= 'red')
plt.show()
